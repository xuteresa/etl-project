# %% [markdown]
# ## Outline
# * Sources:
#     * https://www.kaggle.com/kingburrito666/cannabis-strains/downloads/cannabis-strains.zip/9
#     * https://www.kaggle.com/tictactouka/cannabis
#
# *Steps*
# * Extract data into SQLite file, read tables into DataFrames with extracted columns
#     * Intermediary step: transform those DFs by selecting columns, renaming, and possibly joining based on the foreign key relationships
# * Extract data CSV file, read table into DataFrame with extracted columns
# * Create 3 new DFs with columns from the extracted DFs
# * Load the resulting DataFrames into postgres DB

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract data from SQLite File
# * For reference: ~/classwork/10-Advanced-Data-Storage-and-Retrieval/1/Activities/03-Ins_ReadSQL/Solved/SQLIntoPandas.ipynb

# %% [markdown]
# ### Import SQLite file

# %%
# Create the connection engine
engine = create_engine("sqlite:///Resources/strains.sqlite")
conn = engine.connect()

# %% [markdown]
# ### Using SQL query, combine the strain name, medical effect, and average medical rating

# %%
medical_effects = pd.read_sql('SELECT Strains."name" as strain_name, \
	 MedicalEffects."medical_effect" as "medical_effects", ROUND(AVG(MedicalEffects.rating),2) as medical_rating \
FROM Strains \
INNER JOIN MedicalEffects \
ON Strains.id=MedicalEffects.strain_id \
GROUP BY name',conn)

# %%
medical_effects
# Out:
#                    strain_name                       medical_effects  \
# 0                      00 Kush  Autoimmune Diseases and Inflammation
# 1                         1024                                  Pain
# 2                         2046                              Epilepsy
# 3                 4 Best 4 You                  Psychiatric Symptoms
# 4       5G's Red x Sour Diesel                   Nausea and Vomiting
# 5                 8 Miles High                 Anorexia and Cachexia
# 6                       A.D.D.                  Psychiatric Symptoms
# 7                  AK Widow 47             Dependency and Withdrawal
# 8                        AK-48                 Anorexia and Cachexia
# 9                         AK47                   Nausea and Vomiting
# 10               Acapulco Gold                                  Pain
# 11                  Acid Reign                   Nausea and Vomiting
# 12       Actual C99 Cinderella  Autoimmune Diseases and Inflammation
# 13                  Afgan Kush                  Psychiatric Symptoms
# 14    Afgan Kush x White Widow  Autoimmune Diseases and Inflammation
# 15        Afgan Kush x Yumbolt                                  Pain
# 16               Afghanchitral                                  Pain
# 17                     Afghani                                  Pain
# 18                  Afghani #1                  Psychiatric Symptoms
# 19                Afghani Milk                                  Pain
# 20           Akorn aka Snowbud                                  Pain
# 21                 Alaskan Ice                   Nausea and Vomiting
# 22                 Alpujarrena                 Anorexia and Cachexia
# 23                   Ambulance                                  Pain
# 24                     Amnesia                    Movement Disorders
# 25                Amnesia Haze                   Nausea and Vomiting
# 26                Amnesia Kush                   Nausea and Vomiting
# 27   Amnesia XXL Autoflowering                                  Pain
# 28           Amsterdams' Magic                   Nausea and Vomiting
# 29                  Anesthesia                                  Pain
# ..                         ...                                   ...
# 241   Super Critical Automatic                  Psychiatric Symptoms
# 242           Super Lemon Haze                   Nausea and Vomiting
# 243          Super Silver Haze                  Psychiatric Symptoms
# 244                Super Skunk                   Nausea and Vomiting
# 245   Supersonic Cristal Storm                   Nausea and Vomiting
# 246             Sweet Chunk S1                   Nausea and Vomiting
# 247                   Swiss-xT                                  Pain
# 248                  Tallryder                   Nausea and Vomiting
# 249            Tangerine Dream                   Nausea and Vomiting
# 250                 Temple Flo                   Nausea and Vomiting
# 251                 The Doctor                                  Pain
# 252                  Tora Bora                                  Pain
# 253                      Txaki                            Spasticity
# 254             Tyrone Special                   Nausea and Vomiting
# 255            Ultimate Purple                                  Pain
# 256               Vegan Safari                 Anorexia and Cachexia
# 257                      Viper                   Nausea and Vomiting
# 258               White Dragon                 Anorexia and Cachexia
# 259                 White K.C.                                  Pain
# 260              White Panther                                Asthma
# 261                White Rhino                   Nausea and Vomiting
# 262              White Russian                   Nausea and Vomiting
# 263                White Satin                 Anorexia and Cachexia
# 264                White Skunk                   Nausea and Vomiting
# 265                White Widow                   Nausea and Vomiting
# 266              Wild Thailand                   Nausea and Vomiting
# 267                      X-Dog                                  Pain
# 268                  X-Kush #2                   Nausea and Vomiting
# 269                   Y Griega                                  Pain
# 270                 Yumbolt 47                    Movement Disorders
#
#      medical_rating
# 0              5.00
# 1              4.00
# 2              4.50
# 3              3.00
# 4              5.00
# 5              3.00
# 6              5.00
# 7              2.50
# 8              4.00
# 9              1.84
# 10             5.00
# 11             4.00
# 12             5.00
# 13             3.86
# 14             5.00
# 15             4.00
# 16             4.00
# 17             5.00
# 18             4.00
# 19             3.00
# 20             3.00
# 21             2.83
# 22             2.80
# 23             4.00
# 24             5.00
# 25             4.00
# 26             5.00
# 27             5.00
# 28             3.75
# 29             4.00
# ..              ...
# 241            5.00
# 242            5.00
# 243            4.00
# 244            4.00
# 245            4.65
# 246            4.00
# 247            5.00
# 248            3.20
# 249            3.00
# 250            5.00
# 251            4.75
# 252            5.00
# 253            3.80
# 254            3.71
# 255            3.00
# 256            3.00
# 257            2.67
# 258            4.25
# 259            4.00
# 260            2.00
# 261            3.71
# 262            3.75
# 263            3.05
# 264            3.14
# 265            3.25
# 266            2.00
# 267            4.00
# 268            5.00
# 269            2.63
# 270            4.50
#
# [271 rows x 3 columns]

# %% [markdown]
# # Extract data from cannabis.csv

# %% [markdown]
# ### Convert csv to DataFrame

# %%
file = 'Resources/cannabis.csv'
cannabis_df = pd.read_csv(file)

# %% [markdown]
# ### Create processed DataFrame
# * Extract columns: Strain, Rating, Effects, Flavor, Description
# * Rename columns: strain_name, community_rating, effects, flavor, description

# %%
cannabis_cols = ["Strain", "Type", "Rating", "Effects", "Flavor", "Description"]
cannabis_transformed = cannabis_df[cannabis_cols].copy()

# %%
cannabis_transformed = cannabis_transformed.rename(columns={"Strain": "strain_name",
                                                            "Type":"type",
                                                            "Rating":"community_rating",
                                                            "Effects": "community_effects",
                                                            "Flavor":"flavor",
                                                            "Description":"description"
                                                           })

# %%
cannabis_transformed.drop_duplicates("strain_name", inplace=True)

# %%
cannabis_transformed = cannabis_transformed.reset_index()

# %%
cannabis_transformed=cannabis_transformed.rename(columns={'index':'id'})

# %%
cannabis_transformed['strain_name']=cannabis_transformed['strain_name'].str.replace('-',' ')

# %%
csv_strains = cannabis_transformed[['strain_name']]

# %% [markdown]
# # Transform resulting DataFrames into 3 new ones:
# * strain_effects: strain_name, community_effects, medical_effects
# * strain_ratings: strain_name, community_rating, medical_rating
# * strain_description: strain_name, type, flavor, description

# %%
strains_combined = pd.merge(sql_strains,csv_strains, on='strain_name',how='inner').drop_duplicates()

# %%
strains_combined.set_index('strain_name').reset_index()
# Out:
#               strain_name
# 0               Grape Ape
# 1            Amnesia Haze
# 2         Blackberry Haze
# 3                 Amnesia
# 4              Apple Jack
# 5            Afghan Skunk
# 6               Big White
# 7               Blueberry
# 8           Hawaiian Haze
# 9             Master Kush
# 10             Bangi Haze
# 11                 Django
# 12            White Widow
# 13            Blue Cheese
# 14           707 Headband
# 15          Durban Poison
# 16             Bear Dance
# 17              Gods Gift
# 18              Chocolope
# 19            Silver Haze
# 20         Animal Cookies
# 21          American Kush
# 22      Pineapple Express
# 23                Bandana
# 24            Black Magic
# 25            Cherry Bomb
# 26                 Cheese
# 27              Blue Kush
# 28        Blue Moon Rocks
# 29           Black Diesel
# ...                   ...
# 1038              Odyssey
# 1039       Oldtimers Haze
# 1040        Orange Velvet
# 1041        Oregon Diesel
# 1042    Oregon Pinot Noir
# 1043           Pestilence
# 1044       Pineapple Thai
# 1045       Pink Champagne
# 1046             Pink Pez
# 1047              Pitbull
# 1048         Purple Arrow
# 1049           Purple Cow
# 1050       Purple Gorilla
# 1051  Purple People Eater
# 1052        Purple Voodoo
# 1053       Raspberry Kush
# 1054          Ringos Gift
# 1055          Sour Poison
# 1056          Stardawg 91
# 1057          Stella Blue
# 1058   Strawberry Blondie
# 1059              Sublime
# 1060     Super Sour Widow
# 1061           Swiss Gold
# 1062           Tangenesia
# 1063              The One
# 1064           Tigermelon
# 1065           Watermelon
# 1066      West Coast Dawg
# 1067              Wookies
#
# [1068 rows x 1 columns]

# %%
#filter medical_effects by common strains 
sql_filtered = pd.merge(medical_effects,strains_combined,on="strain_name",how="inner")
sql_filtered.head()
# Out:
#      strain_name      medical_effects  medical_rating
# 0           1024                 Pain            4.00
# 1  Acapulco Gold                 Pain            5.00
# 2        Afghani                 Pain            5.00
# 3    Alaskan Ice  Nausea and Vomiting            2.83
# 4        Amnesia   Movement Disorders            5.00

# %%
csv_effects = cannabis_transformed[['strain_name','community_effects']]
csv_ratings = cannabis_transformed[['strain_name','community_rating']]
sql_effects = medical_effects[['strain_name','medical_effects']]
sql_ratings = medical_effects[['strain_name','medical_rating']]
strain_effects = pd.merge(csv_effects, sql_effects, on="strain_name",how="inner")
strain_ratings = pd.merge(csv_ratings,sql_ratings,on="strain_name",how="inner")
strain_description = cannabis_transformed[['strain_name','type','flavor','description']]

# %%
strain_effects
# Out:
#           strain_name                            community_effects  \
# 0                1024    Uplifted,Happy,Relaxed,Energetic,Creative
# 1       Acapulco Gold    Happy,Uplifted,Euphoric,Energetic,Relaxed
# 2             Afghani         Relaxed,Sleepy,Happy,Euphoric,Hungry
# 3         Alaskan Ice    Euphoric,Uplifted,Happy,Relaxed,Energetic
# 4             Amnesia   Happy,Euphoric,Energetic,Creative,Uplifted
# 5        Amnesia Haze   Happy,Euphoric,Uplifted,Energetic,Creative
# 6          Anesthesia         Hungry,Sleepy,Relaxed,Happy,Euphoric
# 7       Aurora Indica       Relaxed,Sleepy,Happy,Euphoric,Uplifted
# 8          Bangi Haze             Aroused,Uplifted,Euphoric,Hungry
# 9            Big Bang        Relaxed,Sleepy,Happy,Euphoric,Aroused
# 10       Black Domina       Relaxed,Euphoric,Happy,Sleepy,Uplifted
# 11         Black Jack    Relaxed,Happy,Euphoric,Uplifted,Talkative
# 12      Black Russian         Relaxed,Sleepy,Uplifted,Happy,Hungry
# 13        Blue Cheese         Relaxed,Happy,Euphoric,Sleepy,Hungry
# 14           Blue God         Relaxed,Happy,Sleepy,Euphoric,Hungry
# 15      Blue Hawaiian    Happy,Uplifted,Relaxed,Euphoric,Energetic
# 16          Blueberry       Relaxed,Happy,Euphoric,Sleepy,Uplifted
# 17     Blueberry Haze   Happy,Euphoric,Creative,Uplifted,Energetic
# 18       Bruce Banner     Happy,Euphoric,Relaxed,Uplifted,Creative
# 19         Bubba Kush         Relaxed,Happy,Sleepy,Euphoric,Hungry
# 20         Bubble Gum       Happy,Relaxed,Euphoric,Uplifted,Hungry
# 21       Burmese Kush     Uplifted,Relaxed,Happy,Euphoric,Creative
# 22         Cannatonic      Relaxed,Happy,Uplifted,Focused,Euphoric
# 23      Cataract Kush       Relaxed,Happy,Hungry,Euphoric,Uplifted
# 24             Cheese       Relaxed,Happy,Euphoric,Uplifted,Hungry
# 25          Chocolope    Happy,Uplifted,Energetic,Focused,Euphoric
# 26            Chronic      Relaxed,Happy,Giggly,Euphoric,Energetic
# 27        Dance World    Happy,Relaxed,Uplifted,Euphoric,Talkative
# 28        Endless Sky         Euphoric,Relaxed,Happy,Sleepy,Hungry
# 29      Exodus Cheese      Uplifted,Relaxed,Euphoric,Happy,Focused
# ..                ...                                          ...
# 54         Orange Bud    Happy,Euphoric,Energetic,Relaxed,Uplifted
# 55          Pineapple    Happy,Uplifted,Euphoric,Relaxed,Energetic
# 56  Pineapple Express    Happy,Uplifted,Euphoric,Energetic,Relaxed
# 57        Power Plant  Happy,Uplifted,Euphoric,Energetic,Talkative
# 58        Purple Haze    Uplifted,Happy,Euphoric,Relaxed,Energetic
# 59        Purple Thai      Relaxed,Happy,Uplifted,Focused,Creative
# 60       Purple Widow       Relaxed,Euphoric,Hungry,Happy,Creative
# 61         Red Diesel      Euphoric,Hungry,Energetic,Happy,Relaxed
# 62           Rocklock     Relaxed,Happy,Euphoric,Focused,Energetic
# 63             Satori   Creative,Euphoric,Uplifted,Happy,Energetic
# 64         Sensi Star       Relaxed,Euphoric,Sleepy,Happy,Uplifted
# 65             Shaman    Uplifted,Focused,Happy,Energetic,Euphoric
# 66        Shiva Skunk       Euphoric,Relaxed,Uplifted,Happy,Tingly
# 67        Silver Haze    Happy,Euphoric,Relaxed,Talkative,Uplifted
# 68         Snow Ryder              Aroused,Sleepy,Uplifted,Relaxed
# 69   Strawberry Cough    Happy,Uplifted,Euphoric,Energetic,Relaxed
# 70   Super Lemon Haze    Happy,Uplifted,Energetic,Euphoric,Focused
# 71  Super Silver Haze    Happy,Uplifted,Energetic,Euphoric,Relaxed
# 72        Super Skunk         Relaxed,Sleepy,Euphoric,Happy,Hungry
# 73    Tangerine Dream    Happy,Relaxed,Euphoric,Uplifted,Energetic
# 74         The Doctor      Euphoric,Happy,Sleepy,Aroused,Energetic
# 75          Tora Bora       Happy,Relaxed,Sleepy,Euphoric,Creative
# 76              Viper    Energetic,Talkative,Happy,Giggly,Uplifted
# 77       White Dragon       Relaxed,Happy,Hungry,Euphoric,Uplifted
# 78        White Rhino       Relaxed,Happy,Euphoric,Uplifted,Sleepy
# 79      White Russian     Relaxed,Happy,Euphoric,Talkative,Focused
# 80        White Skunk       Relaxed,Happy,Tingly,Euphoric,Uplifted
# 81        White Widow    Happy,Relaxed,Euphoric,Uplifted,Energetic
# 82      Wild Thailand    Euphoric,Happy,Hungry,Talkative,Energetic
# 83           Y Griega    Happy,Energetic,Uplifted,Focused,Euphoric
#
#                          medical_effects
# 0                                   Pain
# 1                                   Pain
# 2                                   Pain
# 3                    Nausea and Vomiting
# 4                     Movement Disorders
# 5                    Nausea and Vomiting
# 6                                   Pain
# 7                    Nausea and Vomiting
# 8                  Anorexia and Cachexia
# 9                    Nausea and Vomiting
# 10                   Nausea and Vomiting
# 11                  Psychiatric Symptoms
# 12                                  Pain
# 13                   Nausea and Vomiting
# 14                 Anorexia and Cachexia
# 15                   Nausea and Vomiting
# 16                                  Pain
# 17                   Nausea and Vomiting
# 18                   Nausea and Vomiting
# 19                   Nausea and Vomiting
# 20                   Nausea and Vomiting
# 21                  Psychiatric Symptoms
# 22                   Nausea and Vomiting
# 23                   Nausea and Vomiting
# 24                   Nausea and Vomiting
# 25                   Nausea and Vomiting
# 26                                  Pain
# 27                            Spasticity
# 28                   Nausea and Vomiting
# 29                   Nausea and Vomiting
# ..                                   ...
# 54                 Anorexia and Cachexia
# 55                   Nausea and Vomiting
# 56                                  Pain
# 57                            Spasticity
# 58                              Glaucoma
# 59                                Asthma
# 60                   Nausea and Vomiting
# 61                   Nausea and Vomiting
# 62                   Nausea and Vomiting
# 63                  Psychiatric Symptoms
# 64                            Spasticity
# 65                 Anorexia and Cachexia
# 66  Autoimmune Diseases and Inflammation
# 67                                  Pain
# 68                   Nausea and Vomiting
# 69                                  Pain
# 70                   Nausea and Vomiting
# 71                  Psychiatric Symptoms
# 72                   Nausea and Vomiting
# 73                   Nausea and Vomiting
# 74                                  Pain
# 75                                  Pain
# 76                   Nausea and Vomiting
# 77                 Anorexia and Cachexia
# 78                   Nausea and Vomiting
# 79                   Nausea and Vomiting
# 80                   Nausea and Vomiting
# 81                   Nausea and Vomiting
# 82                   Nausea and Vomiting
# 83                                  Pain
#
# [84 rows x 3 columns]

# %%
strain_ratings
# Out:
#           strain_name  community_rating  medical_rating
# 0                1024               4.4            4.00
# 1       Acapulco Gold               4.5            5.00
# 2             Afghani               4.3            5.00
# 3         Alaskan Ice               4.4            2.83
# 4             Amnesia               4.3            5.00
# 5        Amnesia Haze               4.3            4.00
# 6          Anesthesia               4.1            4.00
# 7       Aurora Indica               4.4            4.00
# 8          Bangi Haze               0.0            4.50
# 9            Big Bang               4.1            2.18
# 10       Black Domina               4.2            3.00
# 11         Black Jack               4.4            5.00
# 12      Black Russian               4.3            4.50
# 13        Blue Cheese               4.3            3.19
# 14           Blue God               4.7            3.75
# 15      Blue Hawaiian               4.3            3.10
# 16          Blueberry               4.3            2.92
# 17     Blueberry Haze               4.2            4.00
# 18       Bruce Banner               4.6            3.25
# 19         Bubba Kush               4.3            3.33
# 20         Bubble Gum               4.1            3.50
# 21       Burmese Kush               4.2            5.00
# 22         Cannatonic               4.3            4.17
# 23      Cataract Kush               4.4            4.17
# 24             Cheese               4.1            3.29
# 25          Chocolope               4.3            5.00
# 26            Chronic               4.4            4.63
# 27        Dance World               4.6            3.20
# 28        Endless Sky               4.5            4.50
# 29      Exodus Cheese               4.3            3.25
# ..                ...               ...             ...
# 54         Orange Bud               4.3            4.50
# 55          Pineapple               4.2            2.75
# 56  Pineapple Express               4.4            3.25
# 57        Power Plant               4.2            3.08
# 58        Purple Haze               4.3            5.00
# 59        Purple Thai               4.6            5.00
# 60       Purple Widow               4.6            3.67
# 61         Red Diesel               4.2            1.67
# 62           Rocklock               4.6            3.00
# 63             Satori               4.1            4.00
# 64         Sensi Star               4.1            4.00
# 65             Shaman               4.2            3.75
# 66        Shiva Skunk               4.2            5.00
# 67        Silver Haze               4.2            4.00
# 68         Snow Ryder               4.0            4.00
# 69   Strawberry Cough               4.3            2.00
# 70   Super Lemon Haze               4.4            5.00
# 71  Super Silver Haze               4.4            4.00
# 72        Super Skunk               4.2            4.00
# 73    Tangerine Dream               4.4            3.00
# 74         The Doctor               4.4            4.75
# 75          Tora Bora               4.5            5.00
# 76              Viper               4.5            2.67
# 77       White Dragon               4.2            4.25
# 78        White Rhino               4.2            3.71
# 79      White Russian               4.3            3.75
# 80        White Skunk               4.4            3.14
# 81        White Widow               4.3            3.25
# 82      Wild Thailand               3.8            2.00
# 83           Y Griega               4.8            2.63
#
# [84 rows x 3 columns]

# %%
strain_description
# Out:
#                  strain_name    type                        flavor  \
# 0                     100 Og  hybrid           Earthy,Sweet,Citrus
# 1             98 White Widow  hybrid         Flowery,Violet,Diesel
# 2                       1024  sativa       Spicy/Herbal,Sage,Woody
# 3                   13 Dawgs  hybrid     Apricot,Citrus,Grapefruit
# 4                   24K Gold  hybrid          Citrus,Earthy,Orange
# 5                 3 Bears Og  indica                          None
# 6                    3 Kings  hybrid          Earthy,Sweet,Pungent
# 7                     303 Og  indica         Citrus,Pungent,Earthy
# 8                     3D Cbd  sativa          Earthy,Woody,Flowery
# 9                   3X Crazy  indica            Earthy,Grape,Sweet
# 10    3Rd Coast Panama Chunk  hybrid                   Pine,Diesel
# 11                  501St Og  hybrid             Earthy,Pine,Skunk
# 12               5Th Element  indica             Earthy,Woody,Pine
# 13              707 Headband  hybrid          Earthy,Woody,Pungent
# 14               8 Ball Kush  indica            Citrus,Earthy,Pine
# 15                    818 Og  indica         Earthy,Diesel,Flowery
# 16                    831 Og  indica                          None
# 17            9 Pound Hammer  indica            Earthy,Sweet,Berry
# 18                  91 Krypt  indica          Earthy,Pungent,Berry
# 19                      A 10  indica          Citrus,Pungent,Sweet
# 20                     A Dub  hybrid          Diesel,Pepper,Earthy
# 21                   A Train  hybrid           Earthy,Woody,Citrus
# 22                      Acdc  hybrid             Earthy,Pine,Woody
# 23                     Ak 47  hybrid          Earthy,Pungent,Woody
# 24                     Ak 48  hybrid         Earthy,Pungent,Citrus
# 25                  Aberdeen  hybrid  Menthol,Blue,Cheese,Chemical
# 26                Abusive Og  indica            Earthy,Pine,Diesel
# 27             Acapulco Gold  sativa          Earthy,Sweet,Pungent
# 28             Ace Killer Og  indica    Earthy,Diesel,Spicy/Herbal
# 29             Ace Of Spades  indica            Earthy,Sweet,Woody
# ...                      ...     ...                           ...
# 2320          Wonderwoman Og  indica        Flowery,Menthol,Citrus
# 2321    Wonka S Bubbilicious  hybrid        Grape,Strawberry,Sweet
# 2322              Woody Kush  indica             Earthy,Pine,Sweet
# 2323                  Wookie  hybrid            Berry,Earthy,Skunk
# 2324                 Wookies  hybrid        Menthol,Earthy,Pungent
# 2325                Wreckage  hybrid             Earthy,Nutty,Sage
# 2326                  X File  hybrid                          None
# 2327                 X Files  hybrid        Earthy,Citrus,Lavender
# 2328                  X Wing  indica        Earthy,Pungent,Flowery
# 2329               X Tra Chz  hybrid     Pungent,Skunk,Blue,Cheese
# 2330                   Xj 13  hybrid             Citrus,Sweet,Pine
# 2331                 Xxx 420  indica        Sweet,Berry,Grapefruit
# 2332                  Xxx Og  indica             Pine,Woody,Earthy
# 2333                  Xanadu  sativa     Spicy/Herbal,Pepper,Sweet
# 2334                Y Griega  sativa          Earthy,Woody,Flowery
# 2335                 Yeti Og  indica         Earthy,Pungent,Diesel
# 2336                 Yoda Og  indica            Earthy,Skunk,Woody
# 2337             Yodas Brain  indica             Pine,Sage,Flowery
# 2338             Yogi Diesel  hybrid            Diesel,Citrus,Pine
# 2339                Yumboldt  indica     Spicy/Herbal,Earthy,Sweet
# 2340                   Yummy  hybrid          Sweet,Earthy,Pungent
# 2341             Zamaldelica  sativa                          None
# 2342             Zellys Gift  sativa             Sweet,Citrus,Lime
# 2343                     Zen  hybrid          Earthy,Sweet,Flowery
# 2344               Zeta Sage  sativa           Diesel,Pungent,Sage
# 2345                 Zeus Og  hybrid             Earthy,Woody,Pine
# 2346                Zkittlez  indica             Sweet,Berry,Grape
# 2347             Zombie Kush  indica     Earthy,Sweet,Spicy/Herbal
# 2348               Zombie Og  indica          Sweet,Earthy,Pungent
# 2349                Zoom Pie  indica          Berry,Earthy,Pungent
#
#                                             description
# 0     $100 OG is a 50/50 hybrid strain that packs a ...
# 1     The ‘98 Aloha White Widow is an especially pot...
# 2     1024 is a sativa-dominant hybrid bred in Spain...
# 3     13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4     Also known as Kosher Tangie, 24k Gold is a 60%...
# 5     3 Bears OG by Mephisto Genetics is an autoflow...
# 6     The 3 Kings marijuana strain, a holy trinity o...
# 7     The indica-dominant 303 OG is a Colorado strai...
# 8     3D CBD from Snoop Dogg’s branded line of canna...
# 9     Also known as Optimus Prime, the indica-domina...
# 10    3rd Coast Panama Chunk by Bedford Grow is a cr...
# 11    501st OG, bred by Rare Dankness, is an indica-...
# 12    Elemental Seeds crossed Blackberry with All Sp...
# 13    This strain emerged from the Humboldt County, ...
# 14    Bred by Barney’s Farm, 8 Ball Kush is a pure i...
# 15    Named after the telephone area code of the San...
# 16    831 OG, aka Santa Cruz OG, is an indica-domina...
# 17    9 Pound Hammer is an 80% indica strain that cr...
# 18    91 Krypt by DNA Genetics is a potent strain by...
# 19    A-10 has an earthy, hashy taste that provides ...
# 20    Coming from the ever-popular Sour Diesel, OG K...
# 21    A-Train is a hybrid between Mazar I Sharif and...
# 22    ACDC is a sativa-dominant phenotype of the hig...
# 23    Don't let its intense name fool you: AK-47 wil...
# 24    Although it is a hybrid, the AK-48 high leans ...
# 25    Aberdeen is a variety of Agent Orange grown by...
# 26    A popular Californian cut of OG Kush, Abusive ...
# 27    One of the most well-known strains, Acapulco G...
# 28    Ace Killer OG is an indica strain that boasts ...
# 29    Ace of Spades is a creation from TGA Subcool S...
# ...                                                 ...
# 2320                                                NaN
# 2321  A sativa-dominant cross between Pandora's Box ...
# 2322  Don’t be quick to underestimate Woody Kush. Wh...
# 2323  Wookie is a tantalizing cross of Lavender and ...
# 2324  Wookies (not to be confused with the strain “W...
# 2325  Wreckage, bred by T.H. Seeds, is a sativa-domi...
# 2326  Not to be confused with the similar-sounding X...
# 2327  X-Files, bred by Pheno-Type Seeds, is a hybrid...
# 2328  X-Wing is a mid-level indica-dominant strain w...
# 2329  X-tra Chz, bred by MTG Seeds, is a hybrid cros...
# 2330  XJ-13 is a sativa-dominant strain cherished fo...
# 2331  XXX 420 from Ontario, Canada is an indica cros...
# 2332  XXX OG, from parent strains OG Kush and XXX, i...
# 2333  Xanadu, named after the extravagant palace of ...
# 2334  Also known as simply “Y,” the 80% sativa Y Gri...
# 2335  Originally known as the Headband BX, Yeti OG w...
# 2336  Yoda OG, a descendant of the legendary OG Kush...
# 2337  Yoda’s Brain is an indica-dominant cut with de...
# 2338  A pungent mix of Sour Diesel and Northern Ligh...
# 2339  Yumboldt can be hard to find but it is renowne...
# 2340  Yummy is an indica-dominant hybrid that hails ...
# 2341  Zamaldelica by Ace Seeds is a potent sativa-do...
# 2342  Zelly’s Gift by Dragonfly Earth Medicine is a ...
# 2343  With a balanced ratio of THC and CBD, Zen is t...
# 2344  Zeta Sage is a sativa-dominant hybrid that com...
# 2345  Zeus OG is a hybrid cross between Pineapple OG...
# 2346  Zkittlez is an indica-dominant mix of Grape Ap...
# 2347  Zombie Kush by Ripper Seeds comes from two dif...
# 2348  If you’re looking to transform into a flesh-ea...
# 2349  Zoom Pie (also known as Zombie Pie) is a heavy...
#
# [2350 rows x 4 columns]

# %% [markdown]
# # LOAD: Create database and populate

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@127.0.0.1/cannabis_db"
engine = create_engine(f'postgresql://{connection_string}')
conn=engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# []

# %% [markdown]
# ### Load DataFrames into DB

# %%
strain_description.to_sql(name='description', con=engine, if_exists='append', index=True)

# %%
strain_effects.to_sql(name='effects', con=engine, if_exists='append', index=True)

# %%
strain_ratings.to_sql(name='ratings', con=engine, if_exists='append', index=True)
